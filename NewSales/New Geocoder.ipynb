# %%
import pandas as pd
from time import sleep
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import re

# %% [markdown]
# # Read in address data<br>
# ### Note that this code will only work if the correct way to replace spaces in the Address column is with the following string: <i>'%20'</i><br>
# ### Try searching Google maps for an address with spaces and it will automatically fill in the spaces using some string, so just figure out what it is and use it below

# %%
# set the 'space filler' that Google Maps uses on a browser, then read in address data
space_filler = '%20'
df = pd.read_csv('Forsyth_2023.csv')

df['full_address'] = df['Address'] + ' Forsyth County, GA'

# # take random sample from initial CSV
# df = df.sample(n = 1000)
df
# Out:
#       Parcel ID               Address
# 0     035   425       6110 FORMOSA LN  \
# 1     065   178     6940 WHITMAN WALK
# 2     035   117   6430 IVEY CREEK CIR
# 3     075   290      3720 BEAUPORT DR
# 4     083   598        7030 MAJORS RD
# ...         ...                   ...
# 1270  249   070   5290 RIDGE FARMS DR
# 1271  250   092        6785 PAYTON RD
# 1272  174   222      1435 LOBLOLLY LN
# 1273  283   120  7315 TIMBERLINE OVLK
# 1274  214   634    5435 BUCKNELL TRCE
#
#                                             Owner Name
# 0              MCDEERMOND RYAN & | MCDEERMOND JENNIFER  \
# 1                                          EA HOMES LP
# 2                                      ROBERTS JANAE G
# 3                                  BHEG MONTEBELLO LLC
# 4                          ZB HOMES AT MAJORS ROAD LLC
# ...                                                ...
# 1270  MCMAHON JOHN TIMOTHY & | MCMAHON ANGELA ANDERSON
# 1271                         OPENDOOR PROPERTY TRUST 1
# 1272                             BI KEPING & | ZHOU YE
# 1273            PRESTON JOSHUA I & | PRESTON BETHANY N
# 1274                                     DUBIEL WALTER
#
#                                           Owner Address
# 0     MCDEERMOND RYAN & | MCDEERMOND JENNIFER | 6110...  \
# 1     EA HOMES LP | 5775 GLENRIDGE DR BLDG D STE 350...
# 2     ROBERTS JANAE G | 417 ATLAS ST | WHITE SANDS M...
# 3     BHEG MONTEBELLO LLC | 1140 VIRGINIA DR | FORT ...
# 4     ZB HOMES AT MAJORS ROAD LLC | 202 TRIBBLE GAP ...
# ...                                                 ...
# 1270  MCMAHON JOHN TIMOTHY & | MCMAHON ANGELA ANDERS...
# 1271  OPENDOOR PROPERTY TRUST 1 | 410 N SCOTTSDALE R...
# 1272  BI KEPING & | ZHOU YE | 705 EMORY BLUFF | JOHN...
# 1273  PRESTON JOSHUA I & | PRESTON BETHANY N | 7315 ...
# 1274  DUBIEL WALTER | 5435 BUCKNELL TRCE | CUMMING, ...
#
#                                     Grantor                        Grantee
# 0     MCDEERMOND RYAN & MCDEERMOND JENNIFER       ORCHARD PROPERTY III LLC  \
# 1                               EA HOMES LP                STOCKS THOMAS F
# 2                           ROBERTS JANAE G          FLITCH PROPERTIES LLC
# 3                       BHEG MONTEBELLO LLC  TOLL SOUTHEAST LP COMPANY INC
# 4               ZB HOMES AT MAJORS ROAD LLC                   NYCZ TYLER &
# ...                                     ...                            ...
# 1270                 MCMAHON JOHN TIMOTHY &            GIBSON MARK DAVIS &
# 1271              OPENDOOR PROPERTY TRUST I                   KHALAF DALIA
# 1272                    BI KEPING & ZHOU YE                RAMSEY CONNOR &
# 1273   PRESTON JOSHUA I & PRESTON BETHANY N        HIGGINS BRENDAN JAMES &
# 1274                          DUBIEL WALTER          GOPALAN MUTHUKRISHNAN
#
#      Sale Date      Sale Price Qualified Sales
# 0      2/27/23    $511,350.00      Unqualified  \
# 1      2/10/23    $822,440.00      Unqualified
# 2       2/8/23    $397,000.00        Qualified
# 3       2/1/23  $1,681,073.00      Unqualified
# 4       2/3/23    $759,900.00      Unqualified
# ...        ...             ...             ...
# 1270    3/1/23    $601,000.00        Qualified
# 1271    3/1/23    $400,000.00        Qualified
# 1272    3/1/23    $525,000.00        Qualified
# 1273    3/1/23    $430,000.00      Unqualified
# 1274    3/1/23    $475,000.00        Qualified
#
#                           Sales Validity  Acres Parcel  Class   Tax District
# 0             Not Subject to Open Market   0.24             R3             0  \
# 1                                UNKNOWN   0.08             R3             0
# 2                                    NaN   0.65             R3             0
# 3     Sale Includes more than one parcel   0.28             R3             0
# 4                                UNKNOWN   1.01             R3             0
# ...                                  ...    ...            ...           ...
# 1270                                 NaN   1.33             R3             0
# 1271                                 NaN   0.59             R3             0
# 1272                                 NaN   0.70             R3             0
# 1273                             UNKNOWN   0.57             R3             0
# 1274                                 NaN   0.23             R3             0
#
#       Year  Built   Square Ft  Neighborhood Zoning
# 0             2014        3068          795   RES3  \
# 1             2022        2304        25195     MP
# 2             1999        2521          438    R2R
# 3             2022        3583          260   RES3
# 4             2022        3215        25233   RES1
# ...            ...         ...          ...    ...
# 1270          2006        3543         2127     R3
# 1271          1994        1504         2103    R2R
# 1272          1994        2460         2003    R2R
# 1273          1999        2373         2217    R2R
# 1274          2015        3020         1245   RES3
#
#                                  full_address
# 0          6110 FORMOSA LN Forsyth County, GA
# 1        6940 WHITMAN WALK Forsyth County, GA
# 2      6430 IVEY CREEK CIR Forsyth County, GA
# 3         3720 BEAUPORT DR Forsyth County, GA
# 4           7030 MAJORS RD Forsyth County, GA
# ...                                       ...
# 1270   5290 RIDGE FARMS DR Forsyth County, GA
# 1271        6785 PAYTON RD Forsyth County, GA
# 1272      1435 LOBLOLLY LN Forsyth County, GA
# 1273  7315 TIMBERLINE OVLK Forsyth County, GA
# 1274    5435 BUCKNELL TRCE Forsyth County, GA
#
# [1275 rows x 18 columns]

# %%
df['Address_URL'] = df['full_address'].str.replace(' ', space_filler)

# creates the url which will be used to return the response below
df['url'] = ['https://www.google.com/maps/search/' + i for i in df['Address_URL']]
df = df[['full_address', 'url']]
df.head(10)
# Out:
#                                full_address
# 0        6110 FORMOSA LN Forsyth County, GA  \
# 1      6940 WHITMAN WALK Forsyth County, GA
# 2    6430 IVEY CREEK CIR Forsyth County, GA
# 3       3720 BEAUPORT DR Forsyth County, GA
# 4         7030 MAJORS RD Forsyth County, GA
# 5          4825 ASCOT DR Forsyth County, GA
# 6  3530 CHARLESBOURG RUN Forsyth County, GA
# 7      3285 CARSWELL BND Forsyth County, GA
# 8  3555 CHARLESBOURG RUN Forsyth County, GA
# 9      3265 CARSWELL BND Forsyth County, GA
#
#                                                  url
# 0  https://www.google.com/maps/search/6110%20FORM...
# 1  https://www.google.com/maps/search/6940%20WHIT...
# 2  https://www.google.com/maps/search/6430%20IVEY...
# 3  https://www.google.com/maps/search/3720%20BEAU...
# 4  https://www.google.com/maps/search/7030%20MAJO...
# 5  https://www.google.com/maps/search/4825%20ASCO...
# 6  https://www.google.com/maps/search/3530%20CHAR...
# 7  https://www.google.com/maps/search/3285%20CARS...
# 8  https://www.google.com/maps/search/3555%20CHAR...
# 9  https://www.google.com/maps/search/3265%20CARS...

# %% [markdown]
# # Geocode

# %%
options = Options()
options.add_argument("--headless=new")
driver = webdriver.Chrome(options=options)

results = []

for ind in tqdm(df.index, colour='#00FFFF', desc='Geocoding Progress'):
    try:
        driver.get(df['url'][ind])
        sleep(3.7)
        url = driver.current_url
        results.append(url)
    except:
        results.append('error')

print('Geocoding complete!')
# Out:
# Geocoding Progress: 100%|███████████████████| 1275/1275 [23:38<00:00,  1.11s/it]
# Geocoding complete!

# %% [markdown]
# # Create new columns, clean up dataframe, output summary

# %%
lats = []
longs = []

# parse & split the 'results' list 
for item in range(len(results)):
    try:
        found = re.search('/@(.+?),17z', results[item]).group(1)
        lats.append(found.split(',')[0])
        longs.append(found.split(',')[1])
    except:
        lats.append('error')
        longs.append('error')
        
# now add the parsed & cleaned lat/longs as additional columns 
df = df.copy()
df['lat'] = lats
df['long'] = longs
# df = df.drop(columns=['Address_URL', 'url'])
df
# Out:
#                                  full_address
# 0          6110 FORMOSA LN Forsyth County, GA  \
# 1        6940 WHITMAN WALK Forsyth County, GA
# 2      6430 IVEY CREEK CIR Forsyth County, GA
# 3         3720 BEAUPORT DR Forsyth County, GA
# 4           7030 MAJORS RD Forsyth County, GA
# ...                                       ...
# 1270   5290 RIDGE FARMS DR Forsyth County, GA
# 1271        6785 PAYTON RD Forsyth County, GA
# 1272      1435 LOBLOLLY LN Forsyth County, GA
# 1273  7315 TIMBERLINE OVLK Forsyth County, GA
# 1274    5435 BUCKNELL TRCE Forsyth County, GA
#
#                                                     url         lat
# 0     https://www.google.com/maps/search/6110%20FORM...  34.1957814  \
# 1     https://www.google.com/maps/search/6940%20WHIT...   34.107886
# 2     https://www.google.com/maps/search/6430%20IVEY...  34.1989685
# 3     https://www.google.com/maps/search/3720%20BEAU...   34.251921
# 4     https://www.google.com/maps/search/7030%20MAJO...  34.1637053
# ...                                                 ...         ...
# 1270  https://www.google.com/maps/search/5290%20RIDG...       error
# 1271  https://www.google.com/maps/search/6785%20PAYT...       error
# 1272  https://www.google.com/maps/search/1435%20LOBL...       error
# 1273  https://www.google.com/maps/search/7315%20TIMB...       error
# 1274  https://www.google.com/maps/search/5435%20BUCK...       error
#
#              long
# 0     -84.2264594
# 1      -84.220017
# 2     -84.2390137
# 3     -84.1945609
# 4     -84.2040098
# ...           ...
# 1270        error
# 1271        error
# 1272        error
# 1273        error
# 1274        error
#
# [1275 rows x 4 columns]

# %%
# how many addresses will need to be manually geocoded?
manuals = df[df['lat'] == 'error'].shape[0]
total_addresses = df.shape[0]
perc = (manuals / total_addresses) * 100
print(f'Addresses to manually geocode: {manuals} out of {total_addresses}, or only {perc:.1f}% of the total!')
# Out:
# Addresses to manually geocode: 973 out of 1275, or only 76.3% of the total!

# %% [markdown]
# # If everything looks good, export to CSV

# %%
df.to_csv('GeocodedAddresses.csv')
# Out:
# Export complete
